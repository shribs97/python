# %%
class test:
    a=1000
    def insert(self):
        self.b=2000
    def display(self):
        print(test.a)
        print(self.b)
    def update(self):
        test.a=test.a+100
        self.b=self.b+200
t1=test()
t1.insert()
t1.display()
t1.update()
t1.display()
# Out:
# 1000
# 2000
# 1100
# 2200

# %%
print(t1.a)
print(test.a)
print(t1.b)
# Out:
# 1100
# 1100
# 2200

# %%
t2=test()
t2.insert()
t2.display()
# Out:
# 1100
# 2000

# %%
"""WAP to find area of circle"""
import math
class circle:
    def insert(self,r):
        self.r=r
    def area(self):
        area1=math.pi*self.r*self.r
        print(area1)
t1=circle()
t1.insert(int(input()))
t1.area()
# Out:
# 7
# 153.93804002589985

# %%
class rectangle:
    def area(self,l,b):
        self.l=l
        self.b=b
    def display(self): 
        print(self.l*self.b)
a=rectangle()
a.area(10,20)
a.display()
# Out:
# 200

# %%
class test:
    def __init__(self):
        self.a=100
        self.b=200
    def display(self):
        print(self.a,self.b)
        
t1=test()
t1.display()
# Out:
# 100 200

# %%
class test:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def display(self):
        print(self.a,self.b)
        
t1=test(100,200)
t1.display()
# Out:
# 100 200

# %%
t2=test(19,10)
t2.display()
# Out:
# 19 10

# %%
"""WAP to find area of triangle ,1/2b*h"""
class triangle:
    def __init__(self,b,h):
        self.b=b
        self.h=h
    def area(self):
        print(0.5*self.b*self.h)
t1=triangle(10,5)
t1.area()
# Out:
# 25.0

# %%
import math
class test:
    def square(n):
        print(n*n)
    def add(a,b):
        print(a+b)
    def fact(f):
        s=math.factorial(f)
        return s
test.square(19)
test.add(10,2)
f=test.fact(4)
print(f)
# Out:
# 361
# 12
# 24

# %%
"""WAP devlope bankeing application  includeing all type of varibles and non static method"""

class cust:
    bname="cbi"
    

    def __init__(self,nm,aid,bal,add):
        self.nm=nm
        self.aid=aid
        self.bal=bal
        self.add=add
    def cust_in(self):
        print(self.nm,self.aid,self.bal,self.add)
    def ck_bal(self):
        print("update balance ",self.bal)
    def deposite(self,amt):
        self.bal+=amt
        
    def withdrawl(self,amt):
        if(self.bal>amt):
            if(self.bal-amt>2000):
                self.bal-=amt
            else:
                print("maintain balance")
        else:
            print("Insuffcient balance")
t1=cust("shri","304",550000000,"Pune")
t1.cust_in()
t1.ck_bal()
t1.deposite(50000)
t1.withdrawl(4500)
# Out:
# shri 304 550000000 Pune
# update balance  550000000

# %%
t1.ck_bal()
# Out:
# update balance  550045500

# %%
t2=cust("shri","304",550,"Pune")
t2.cust_in()
t2.ck_bal()
t2.deposite(10)
t2.withdrawl(4500)
t2.withdrawl(500)
# Out:
# shri 304 550 Pune
# update balance  550
# Insuffcient balance
# maintain balance

# %%
"""WAP to create student class and find result """
class student:
    College="JSPM RSCOE Tathawade"
    def __init__(self,name,roll,a,b,c):
        self.name=name
        self.roll=roll
        self.a=a
        self.b=b
        self.c=c
    def detail(self):
        print(student.College)
        print(self.name)
        print(self.roll)
        x=self.a+self.b+self.c
        print(x)
        print("Pass") if self.a>=35 and self.b>=35 and self.c>=35 else print("Fail")
t1=student("Saurabh",25,75,25,75)
t1.detail()
# Out:
# JSPM RSCOE Tathawade
# Saurabh
# 25
# 175
# Fail

# %% [markdown]
# setter method used to set the value to non static variable
# getattr method used to return the value  from the class

# %%
class stud:
    def set_nm(self,nm):
        self.nm=nm
    def set_rno(self,rno):
        self.rno=rno
    def set_mrks(self,mrks):
        self.mrks=mrks
    def get_nm(self):
        return self.nm
    def get_rno(self):
        return self.rno
    def get_mrks(self):
        return self.mrks
t1=stud()
t1.set_nm("Saurabh")
t1.set_rno(72)
t1.set_mrks(33)
a=t1.get_nm()
b=t1.get_rno()
c=t1.get_mrks()
print(a,b,c)
# Out:
# Saurabh 72 33

# %%
"""
oops principle
class-
object,
encapulation
inheritance
polymorphism
interface and abstract classess

class is container which contans data and relate doperation in single entity
class is collection of data and releated oprations
data can represented by variables, and oprations can be represented by methods
we can declare three types of variable in class 1]static variables,2]non static variable 2]local variable
we can declare three types of method in class 1]static method 2] non static method 3]class method

static variable the variable which are declared with in class and outside of all methods  those variables are called as static variable
 we can access a static variable with in class  by useing class name and outside of class byuseig refrance variable object name .
for static variable memory is alloted when class is stored.

Non static variable:-
the varibale which are declared within a class and within a method those variables are called as non static variable.
we can access , create, update non static variables, within a class and i=outside of class by useing self keyword and outside of class by useing refrance variable name.

Object-its is instance of class, by createing object memory are alloted for the data members of class .

Constrcutor-
constructor is special type of method ,constructor is invoked dureing creaation of object, and we can initialize non sttatic variable automatically useing constructor


static method:
accessed through class name,no noeed to object create
"""

# %% [markdown]
# Cyclic inheritance
# the concept of inherting properties of sub class to supper class
# python does not support cyclic inheritance
# class x(z):
#     pass
# class y(x):
#     pass
# class z(y):
#     pass
#  a=z()

# %% [markdown]
# # Polymorphism

# %% [raw]
# defineing one thing in number of forms is called polymorphis
# polymorphism supported by two process
# 1]method overloadeing
# 2]method overriddeing
# 1]method overloadeing
# the concept of defininf multiple methods with same name with diffrent number of parameeters is called as method overlodeing
# method overloadeing is partially supported by ython programeing
# 2]
# the concept of defineing multipe method with same number of parammeters with diffrent
#  no of parammeters in oe is superclass and another is sublass
#  whenever we overrideing superclass and subclass then by defaul sub class method executed if subclass is create

# %%
class x:
    def m1(self):
        print("no")
    def m1(self,a):
        print("one")
    def m1(self,a,b):
        print("two")
a=x()
a.m1(10,20)
# Out:
# two

# %%
class x:
    def add(self,s,*args):
        if(s=="int"):
            sum=0
        if(s=="str"):
            sum=""
        for i in args:
            sum+=i
        print(sum)
a=x()
a.add("int",20,75,76,99)
a.add("str","jspm"," ","rscoe")
# Out:
# 270
# jspm rscoe

# %%
class x:
    def m1(self):
        print("M1")
    def __str__(self):
        return "Python"
a=x()
a.m1()
p=a.__str__()
print(p)
# Out:
# M1
# Python

# %%
def x(c):
    c=c**2
    print(c)
    return x(c)
x(5)
# Out:
# 25
# 625
# 390625
# 152587890625
# 23283064365386962890625
# 542101086242752217003726400434970855712890625
# 293873587705571876992184134305561419454666389193021880377187926569604314863681793212890625
# 86361685550944446253863518628003995711160003644362813850237034701685918031624270579715075034722882265605472939461496635969950989468319466936530037770580747746862471103668212890625
# 
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
print("c")
# Out:
# c

# %%
class x:
    def m1(self):
        print("m1 super")
    def m2(self):
        print("m2")
class y(x):
    def m1(self):
        print("in m1 y")
        super().m1()
y1=y()
y1.m1()
y1.m2()
# Out:
# in m1 y
# m1 super
# m2

# %%
y1.m1()
# Out:
# in m1 y
# m1 super
